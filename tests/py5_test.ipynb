# %%
# %gui osx

# %%
import py5_tools
import py5

# %load_ext py5
# Out:
# Picked up JAVA_TOOL_OPTIONS: --enable-native-access=ALL-UNNAMED

# %%
# %%py5draw 300 200
#
# # fix scale bug. This should be able to be removed when the bug is fixed.
# py5.scale(0.5)
#
# # make the background light gray
# py5.background(240)
#
# # draw a red square
# py5.fill(255, 0, 0)
# py5.rect_mode(py5.CENTER)
# py5.rect(170, 80, 100, 100)
#
# # add a thick green line
# py5.stroke(0, 255, 0)
# py5.stroke_weight(15)
# py5.line(40, 30, 220, 180)

# %%
# %%py5draw 300 200
#
# # fix scale bug. This should be able to be removed when the bug is fixed.
# py5.scale(0.5)
#
# def pick_random_fill():
#     py5.fill(py5.random(255), py5.random(255), py5.random(255))
#
# py5.background(240)
# py5.rect_mode(py5.CENTER)
#
# for i in range(100):
#     pick_random_fill()
#     py5.rect(py5.random(py5.width), py5.random(py5.height), 10, 10)

# %%
def setup():
    py5.size(500, 400, py5.P2D)
    py5.background(240)
    py5.rect_mode(py5.CENTER)

def draw():
    random_x = py5.random(py5.width)
    random_y = py5.random(py5.height)
    py5.rect(random_x, random_y, 10, 10)

py5.run_sketch()
print('the sketch is running!')
# Out:
# the sketch is running!
# 2025-11-12 22:51:09.324 python[57302:1384774] NewtNSView::dealloc: softLock still hold @ dealloc!

# %%
def setup():
    py5.size(400, 400)
    py5.rect_mode(py5.CENTER)


def draw():
    py5.square(py5.mouse_x, py5.mouse_y, 10)


def mouse_clicked():
    py5.fill(py5.random_int(255), py5.random_int(255), py5.random_int(255))


py5.run_sketch()
